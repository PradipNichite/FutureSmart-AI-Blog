# %%
linkedin_url = "https://www.linkedin.com/in/pradipnichite/"

# %% [markdown]
# # ProxyCurl https://nubela.co/proxycurl/docs#people-api
#
# - Pricing - https://nubela.co/proxycurl/pricing
# - No Posts section

# %%
import requests
import time

api_key = ''
headers = {'Authorization': 'Bearer ' + api_key}
api_endpoint = 'https://nubela.co/proxycurl/api/v2/linkedin'
params = {
    'linkedin_profile_url': linkedin_url,
    'skills': 'include',
    'use_cache': 'if-recent',
    'fallback_to_cache': 'never',
}
start_time = time.time()
response = requests.get(api_endpoint,
                        params=params,
                        headers=headers)

end_time = time.time()
time_taken = end_time - start_time
print("Time taken:", time_taken)

data = response.json()
# Out:
# Time taken: 1.2400243282318115

# %%
data
# Out:
# {'public_identifier': 'pradipnichite',
#  'profile_pic_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/pradipnichite/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20231226%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20231226T140742Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=31ed42fcde14ed8c34c58a44d7ce6140f710776d4c69f480427a6d01680912fa',
#  'background_cover_image_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/person/pradipnichite/cover?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20231226%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20231226T140742Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=c3a4363d504c75034096d6ebb0dd876c59a0b41c88e4560bd383d66ab09695f3',
#  'first_name': 'Pradip',
#  'last_name': 'Nichite',
#  'full_name': 'Pradip Nichite',
#  'follower_count': 20901,
#  'occupation': 'Founder & Lead Data Scientist at FutureSmart AI',
# ...

# %%
', '.join(list(data.keys()))
# Out:
# 'public_identifier, profile_pic_url, background_cover_image_url, first_name, last_name, full_name, follower_count, occupation, headline, summary, country, country_full_name, city, state, experiences, education, languages, accomplishment_organisations, accomplishment_publications, accomplishment_honors_awards, accomplishment_patents, accomplishment_courses, accomplishment_projects, accomplishment_test_scores, volunteer_work, certifications, connections, people_also_viewed, recommendations, activities, similarly_named_profiles, articles, groups, skills, inferred_salary, gender, birth_date, industry, extra, interests, personal_emails, personal_numbers'

# %%
for i in data.keys():
  print(i)
# Out:
# public_identifier
# profile_pic_url
# background_cover_image_url
# first_name
# last_name
# full_name
# follower_count
# occupation
# headline
# summary
# country
# country_full_name
# city
# state
# experiences
# education
# languages
# accomplishment_organisations
# accomplishment_publications
# accomplishment_honors_awards
# accomplishment_patents
# accomplishment_courses
# accomplishment_projects
# accomplishment_test_scores
# volunteer_work
# certifications
# connections
# people_also_viewed
# recommendations
# activities
# similarly_named_profiles
# articles
# groups
# skills
# inferred_salary
# gender
# birth_date
# industry
# extra
# interests
# personal_emails
# personal_numbers

# %% [markdown]
# # Fresh LinkedIn Profile Data https://rapidapi.com/freshdata-freshdata-default/api/fresh-linkedin-profile-data/
#
# - Pricing - https://rapidapi.com/freshdata-freshdata-default/api/fresh-linkedin-profile-data/pricing
#
# - No posts section

# %%
import requests
import time

url = "https://fresh-linkedin-profile-data.p.rapidapi.com/get-linkedin-profile"

querystring = {"linkedin_url":linkedin_url,"include_skills":"true"}

headers = {
	"X-RapidAPI-Key": "",
	"X-RapidAPI-Host": "fresh-linkedin-profile-data.p.rapidapi.com"
}
start_time = time.time()
response = requests.get(url, headers=headers, params=querystring)

end_time = time.time()
time_taken = end_time - start_time
print("Time taken:", time_taken)

data3 = response.json()
# Out:
# Time taken: 5.219818115234375

# %%
data3
# Out:
# {'data': {'about': "🚀 I'm a Top Rated Plus NLP freelancer on Upwork with over $100K in earnings and a 100% Job Success rate. This journey began in 2022 after years of enriching experience in the field of Data Science.\n\nhttps://www.upwork.com/freelancers/pradipnichite\n\n📚 Starting my career in 2013 as a Software Developer focusing on backend and API development, I soon pursued my interest in Data Science by earning my M.Tech in IT from IIIT Bangalore, specializing in Data Science (2016 - 2018).\n\n💼 Upon graduation, I carved out a path in the industry as a Data Scientist at MiQ (2018 - 2020) and later ascended to the role of Lead Data Scientist at Oracle (2020 - 2022).\n\n🌐 Inspired by my freelancing success, I founded FutureSmart AI in September 2022. We provide custom AI solutions for clients using the latest models and techniques in NLP.\n\n🎥 In addition, I run AI Demos, a platform aimed at educating people about the latest AI tools through engaging video demonstrations.\n\n🧰 My
# ...

# %%
', '.join(data3['data'])
# Out:
# 'about, city, company, company_domain, company_employee_range, company_industry, company_linkedin_url, company_logo_url, company_website, company_year_founded, connections_count, country, current_company_join_month, current_company_join_year, educations, email, experiences, first_name, followers_count, full_name, headline, hq_city, hq_country, hq_region, job_title, languages, last_name, linkedin_url, location, phone, profile_id, profile_image_url, public_id, school, skills, state, urn'

# %%
for i in data3['data']:
  print(i)
# Out:
# about
# city
# company
# company_domain
# company_employee_range
# company_industry
# company_linkedin_url
# company_logo_url
# company_website
# company_year_founded
# connections_count
# country
# current_company_join_month
# current_company_join_year
# educations
# email
# experiences
# first_name
# followers_count
# full_name
# headline
# hq_city
# hq_country
# hq_region
# job_title
# languages
# last_name
# linkedin_url
# location
# phone
# profile_id
# profile_image_url
# public_id
# school
# skills
# state
# urn

# %% [markdown]
# # Scraping-bot.io https://www.scraping-bot.io/
#
#
# - Pricing - https://www.scraping-bot.io/pricing-web-scraper-api/
#
# - Real-time scraping
#
# - Works better as compared to ProxyCurl
#
# - Contains posts section for the previous 4 days

# %%
import requests
import time
import json
from time import sleep

username = ''
apiKey = ''
scraper = 'linkedinProfile'
url = linkedin_url

apiEndPoint = "http://api.scraping-bot.io/scrape/data-scraper"
apiEndPointResponse = "http://api.scraping-bot.io/scrape/data-scraper-response?"

payload = json.dumps({"url": url, "scraper": scraper})
headers = {
    'Content-Type': "application/json"
}

start_time = time.time()
response = requests.request("POST", apiEndPoint, data=payload, auth=(username, apiKey), headers=headers)
if response.status_code == 200:
    print(response.json())
    print(response.json()["responseId"])
    responseId = response.json()["responseId"]

    pending = True
    count = 0
    while pending:
        count+=1
        # sleep 5s between each loop, social-media scraping can take quite long to complete
        # so there is no point calling the api quickly as we will return an error if you do so
        sleep(5)
        finalResponse = requests.request("GET", apiEndPointResponse + "scraper=" + scraper + "&responseId=" + responseId
                                         , auth=(username, apiKey))
        result = finalResponse.json()
        if type(result) is list:
            pending = False
            print(finalResponse.text)
        elif type(result) is dict:
            if "status" in result and result["status"] == "pending":
                print(result["message"])
                continue
            elif result["error"] is not None:
                pending = False
                print(json.dumps(result, indent=4))

else:
    print(response.text)

end_time = time.time()
time_taken = end_time - start_time
print("Time taken:", time_taken)
# Out:
# {'responseId': '658ade4bfd5c2e640a170749'}
# 658ade4bfd5c2e640a170749
# Scraping is not finished for this request, try again in a few
# Scraping is not finished for this request, try again in a few
# Scraping is not finished for this request, try again in a few
# ...

# %%
result
# Out:
# [{'url': 'https://www.linkedin.com/in/pradipnichite/?_l=en',
#   'name': 'Pradip Nichite',
#   'current_company': {'name': 'FutureSmart AI',
#    'link': 'https://in.linkedin.com/company/futuresmartai?trk=public_profile_topcard-current-company'},
#   'avatar': 'https://media.licdn.com/dms/image/D4D03AQFU1AiD1jO0fg/profile-displayphoto-shrink_200_200/0/1674710874602?e=2147483647&v=beta&t=KWT0V2ZwkvcBxBK3vACgifZijNQ9JcQrlJdnW6n4yF8',
#   'about': "🚀 I'm a Top Rated Plus NLP freelancer on Upwork with over $100K in earnings and a 100%…",
#   'city': 'Mumbai, Maharashtra, India',
#   'followers': '21K followers',
#   'following': '500+ connections',
#   'educations_details': 'International Institute of Information Technology – Bangalore',
#   'posts': [{'title': 'How does a machine learning algorithm learn? (with intuition and math that you already know )',
#     'attribution': 'By Pradip Nichite',
# ...

# %%
for i in result[0].keys():
  print(i)
# Out:
# url
# name
# current_company
# avatar
# about
# city
# followers
# following
# educations_details
# posts
# experience
# education
# certifications
# courses
# languages
# groups
# people_also_viewed
# activities
# recommendations
# recommendations_count
# volunteer_experience
# projects
# patents
# publications
# awards
# contributions
# organizations
# timestamp

# %% [markdown]
# # Linkedin Data Scraper https://rapidapi.com/mgujjargamingm/api/linkedin-data-scraper
#
# - Pricing: https://rapidapi.com/mgujjargamingm/api/linkedin-data-scraper/pricing
# - No posts section, contains featured section

# %%
import requests
import time

url = "https://linkedin-data-scraper.p.rapidapi.com/person"

payload = { "link": linkedin_url }
headers = {
	"content-type": "application/json",
	"X-RapidAPI-Key": "",
	"X-RapidAPI-Host": "linkedin-data-scraper.p.rapidapi.com"
}

start_time = time.time()
response = requests.post(url, json=payload, headers=headers)
end_time = time.time()
time_taken = end_time - start_time
print("Time taken:", time_taken)

data4 = response.json()
# Out:
# Time taken: 2.758809804916382

# %%
data4
# Out:
# {'success': True,
#  'status': 200,
#  'data': {'data': {'firstName': 'Pradip',
#    'lastName': 'Nichite',
#    'fullName': 'Pradip Nichite',
#    'publicIdentifier': 'pradipnichite',
#    'headline': 'Top Rated Plus - NLP Freelancer | Custom NLP Solutions | GPT-4 | AI Demos',
#    'associatedHashtags': 'Talks about #nlp, #gpt3, #freelancing, #machinelearning, and #artificialintelliegence',
#    'connections': 1,
#    'followers': 21404,
#    'emailRequired': False,
#    'creatorWebsite': {'name': 'My Youtube Channel  ',
#     'link': 'https://www.youtube.com/c/PradipNichiteAI'},
#    'openConnection': True,
#    'urn': 'ACoAAA0aCz0B_r8k5MLp8w-N_giV2qCoIIYco6w',
# ...

# %%
for i in data4['data']['data'].keys():
  print(i)
# Out:
# firstName
# lastName
# fullName
# publicIdentifier
# headline
# associatedHashtags
# connections
# followers
# emailRequired
# creatorWebsite
# openConnection
# urn
# updates
# about
# experiences
# educations
# liceseAndCenrtificates
# honorsAndAwards
# languages
# volunteerAndAwards
# verifications
# promos
# highlights
# projects
# publications
# patents
# courses
# testScores
# organizations
# volunteerCauses
# skills

# %% [markdown]
# # Comments
# - Scraping-bot.io tracks user activites for a timeframe of around the last 4 days

# %% [markdown]
# # Other APIs
# - Zyla - https://zylalabs.com/api-marketplace/data/data+extractor+from+linkedin+api/147? (Requires debit card details for usage)
#
# - Piloterr - https://docs.piloterr.com/v2/api-reference/linkedin/profile/info (Requires debit card details for usage)
#
# - https://brightdata.com/products/web-scraper/linkedin?pscd=get.brightdata.com&ps_partner_key=YWltdWx0aXBsZW91MjI4MA&sid=linkedin-scrapers&ps_xid=MCcxArmemdc2LF&gsxid=MCcxArmemdc2LF&gspk=YWltdWx0aXBsZW91MjI4MA&utm_source=affiliates&utm_campaign=YWltdWx0aXBsZW91MjI4MA#t_l3a017p2qlpzku9mk.1 (Requires business email id)
